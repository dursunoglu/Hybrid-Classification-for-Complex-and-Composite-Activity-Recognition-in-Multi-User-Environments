# %% [markdown]
# # Quick Start
#
# This notebook demonstrates how to load the synthetic multi-user HAR dataset and inspect the files.

# %%
import pandas as pd
from pathlib import Path

data_dir = Path('../data')
raw = pd.read_csv(data_dir / 'preview_first_2000_rows.csv')
raw.head()

# %% [markdown]
# To train the baseline model, run from the repository root:
#
# ```bash
# python src/train_baseline.py --data_dir data --task atomic_activity
# ```
